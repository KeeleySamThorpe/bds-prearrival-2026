# %% [markdown]
# <a href="https://colab.research.google.com/github/KeeleySamThorpe/bds-prearrival-2026/blob/main/Lab_session_1_Demo_23_9_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 42

# %%
x
# Out:
# 42

# %%
type (x)
# Out:
# int

# %%
id (x)
# Out:
# 10447720

# %%
y = x

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# int

# %%
id(x)
# Out:
# 10447720

# %%
id(y)
# Out:
# 10447720

# %%
x
# Out:
# 42

# %%
y = 23

# %%
x + y
# Out:
# 65

# %%
x - y
# Out:
# 19

# %%
y - x
# Out:
# -19

# %%
y * x
# Out:
# 966

# %%
x * 10
# Out:
# 420

# %%
x / 2
# Out:
# 21.0

# %%
x / 5
# Out:
# 8.4

# %%
x // 5
# Out:
# 8

# %%
x ** 2
# Out:
# 1764

# %%
x = 101.123

# %%
type (x)
# Out:
# float

# %%
y = 10.0

# %%
type (y)
# Out:
# float

# %%
x
# Out:
# 101.123

# %%
x + 12
# Out:
# 113.123

# %%
x = 'Hello world'

# %%
type (x)
# Out:
# str

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
x = 'hello world'

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
len(x)
# Out:
# 11

# %%
x = 42

# %%
len(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_883/619855596.py in <cell line: 0>()
# ----> 1 len(x)
#
# TypeError: object of type 'int' has no len()
